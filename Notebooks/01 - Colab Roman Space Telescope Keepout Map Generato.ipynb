# %% [markdown]
# ### Roman Observatory Coronagraphic Instrument Observability Tool
#
# This version of the tool is intended for use with Google Colab.  To run the offline tool, use Notebook Roman Space Telescope Keepout Map Generator.ipynb.

# %%
# This cell should *only* be executed if running the notebook in Google Colab
import os
# Go to roman_pointing repository and update
roman_pointing_dir = 'roman_pointing'
drive_dir = "/content/drive/MyDrive/"
rp_path = os.path.join(drive_dir, roman_pointing_dir, "roman_pointing")
notebooks_path = os.path.join(rp_path, "Notebooks")
os.chdir(rp_path)
# !git pull

# Install the backend and all requirements - this can also take a little while
# !pip install .

# Refresh package list to pick up new installations
import site
site.main()

# Change to the Notebooks directory
os.chdir(notebooks_path)

# need to import third party jupyter widget
from google.colab import output
output.enable_custom_widget_manager()

# import widget and run
from roman_pointing.roman_observability import launch_ui
launch_ui()
